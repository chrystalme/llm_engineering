# %% [markdown]
# # ARIA — Automated Real-time Investment Alert Agent
#
# Multi-agent pipeline that monitors commodities, stocks, indices, and crypto; runs technical and sentiment analysis; and sends Pushover alerts when opportunities meet the score threshold.
#
# **Agents:** DATA_FETCHER → TECH_ANALYST → SENTIMENT_AGENT → DECISION_AGENT → NOTIFIER
#
# This notebook runs the Gradio UI with a colored log stream per agent and a results table.

# %%
# Ensure the chrys project root is on the path
import sys
import os

cwd = os.getcwd()
if os.path.basename(cwd) == "chrys" and "community_contributions" in cwd:
    chrys_dir = cwd
else:
    chrys_dir = os.path.join(cwd, "week8", "community_contributions", "chrys")
    if not os.path.isdir(chrys_dir):
        chrys_dir = cwd
if chrys_dir not in sys.path:
    sys.path.insert(0, chrys_dir)
os.chdir(chrys_dir)

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Uncomment to use the Modal-deployed pipeline instead of local run

os.environ["USE_MODAL"] = "1"

# %%
import logging
logging.getLogger().setLevel(logging.INFO)

# %% [markdown]
# ## Launch the Gradio app
#
# Click **Run pipeline** to run all agents. The log panel shows each agent's output in a distinct color; the table updates with the last run's decisions (Asset, Tech score, Sentiment, Final score, ALERT/SKIP).

# %%
from app import build_ui

ui = build_ui()
ui.launch(share=False, inbrowser=True)
# Out:
# /Users/chrys/Documents/AI_Engineering/llm_engineering/week8/community_contributions/chrys/app.py:242: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(title="ARIA — Market Intelligence", theme=gr.themes.Soft(), css="""
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# python(15382) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# DEBUG: putting 10 records into result_queue
